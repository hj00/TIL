# %%
#CSV,Clipboard,Excel,JSON,HTML,PythonPickling,Feather,Msgpack,HDFS,SAS,STATA,SQL,GoogleBigQuery 파일 입출력 가능
#%%writefile 매직 명령 : csv 
import pandas as pd

# %%
# %%writefile ~/sample.csv
# c1,c2,c3
# 1,1.11,one
# 2,2.22,two
# 3,3.33,three
# #csv file 생성
# Out:
# Overwriting C:\Users\student/sample.csv

# %%
#csv 파일 입력
pd.read_csv('~/sample.csv')#csv file read
# Out:
#              c1    c2     c3
# 0             1  1.11    one
# 1             2  2.22    two
# 2             3  3.33  three
# 3  #csv file 생성   NaN    NaN

# %%
# %%writefile ~/sample2.csv
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting C:\Users\student/sample2.csv

# %%
pd.read_csv('~/sample2.csv', names=['c1','c2','c3'])
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
pd.read_csv('~/sample.csv', index_col='c1') # 테이블 내 특정 칼럼을 인덱스 지정하고 싶은 경우
# Out:
#                 c2     c3
# c1
# 1             1.11    one
# 2             2.22    two
# 3             3.33  three
# #csv file 생성   NaN    NaN

# %%
# %%writefile ~/sample3.txt
# c1       c2        c3       c4
# 0.179181 -1.538472 1.347553 0.43381
# 1.024209 0.087307 -1.281997 0.49265
# 0.417899 -2.002308 0.255245 -1.10515
# Out:
# Overwriting C:\Users\student/sample3.txt

# %%
pd.read_table('~/sample3.txt', sep='\s+')
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
#자료 중에서 건너뛸 행이 있으면 skiprows사용
#writefile명령의 경우 writefile만 사용가능(주석도 불가)

# %%
# %%writefile ~/sample4.txt
# 파일 제목: sample4.txt
# 데이터 포맷의 설명:
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting C:\Users\student/sample4.txt

# %%
pd.read_csv('~/sample4.txt', skiprows=[0,1])
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# %%writefile ~/sample5.csv
# c1,c2,c3
# 1,1.11,one
# 2,,two
# 3,3.33,three
# Out:
# Overwriting C:\Users\student/sample5.csv

# %%
df=pd.read_csv('~/sample5.csv', na_values=['누락'])
df
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2   NaN    two
# 2   3  3.33  three

# %%
#csv 파일 출력
df.to_csv('~/sample6.csv')

# %%
df2=df.to_csv('~/smple6.csv', sep=',')
df2

# %%
df2.to_csv('~/sample7.txt', sep='|')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-f14c6711fd47> in <module>()
# ----> 1 df2.to_csv('~/sample7.txt', sep='|')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
df3=pd.read_csv('~/sample7.txt', sep='|')
df
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2   NaN    two
# 2   3  3.33  three

# %%
df3.to_csv('~/sample8.csv', na_rep='누락')

# %%
df4=pd.read_csv('~/sample8.csv', encoding='iso-8859-1')
df4
# Out:
#    Unnamed: 0  Unnamed: 0.1  c1    c2     c3
# 0           0             0   1  1.11    one
# 1           1             1   2  ´©¶ô    two
# 2           2             2   3  3.33  three

# %%
df.index=["a","b","c"]
df
# Out:
#    c1    c2     c3
# a   1  1.11    one
# b   2   NaN    two
# c   3  3.33  three

# %%
df.to_csv('~/sample9.csv', index=False, header=False)

# %%
df5=pd.read_csv('~/sample9.csv')
df5
# Out:
#    1  1.11    one
# 0  2   NaN    two
# 1  3  3.33  three

# %%
#인터넷 상의 csv 파일 입력
df=pd.read_csv('http://www.google.com/finance/historical?q=NASDAQ%3AAAPL&output=csv')

# %%
df
# Out:
#           Date    Open    High     Low   Close     Volume
# 0     2-Aug-17  159.28  159.75  156.16  157.14   69936800
# 1     1-Aug-17  149.10  150.22  148.41  150.05   35368645
# 2    31-Jul-17  149.90  150.33  148.13  148.73   19845920
# 3    28-Jul-17  149.89  150.23  149.19  149.50   17213653
# 4    27-Jul-17  153.75  153.99  147.30  150.56   32476337
# 5    26-Jul-17  153.35  153.93  153.06  153.46   15780951
# 6    25-Jul-17  151.80  153.84  151.80  152.74   18853932
# 7    24-Jul-17  150.58  152.44  149.90  152.09   21493160
# 8    21-Jul-17  149.99  150.44  148.88  150.27   26252630
# 9    20-Jul-17  151.50  151.74  150.19  150.34   17243748
# 10   19-Jul-17  150.48  151.42  149.95  151.02   20922969
# 11   18-Jul-17  149.20  150.13  148.67  150.08   17868792
# 12   17-Jul-17  148.82  150.90  148.57  149.56   23793456
# 13   14-Jul-17  147.97  149.33  147.33  149.04   20132061
# 14   13-Jul-17  145.50  148.49  145.44  147.77   25199373
# ...

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   2-Aug-17  159.28  159.75  156.16  157.14  69936800
# 1   1-Aug-17  149.10  150.22  148.41  150.05  35368645
# 2  31-Jul-17  149.90  150.33  148.13  148.73  19845920
# 3  28-Jul-17  149.89  150.23  149.19  149.50  17213653
# 4  27-Jul-17  153.75  153.99  147.30  150.56  32476337

# %%
df.tail(10)
# Out:
#           Date    Open    High     Low   Close    Volume
# 241  17-Aug-16  109.10  109.37  108.34  109.22  25355976
# 242  16-Aug-16  109.63  110.23  109.21  109.38  33794448
# 243  15-Aug-16  108.14  109.54  108.08  109.48  25868209
# 244  12-Aug-16  107.78  108.44  107.78  108.18  18660434
# 245  11-Aug-16  108.52  108.93  107.85  107.93  27484506
# 246  10-Aug-16  108.71  108.90  107.76  108.00  24008505
# 247   9-Aug-16  108.23  108.94  108.01  108.81  26315204
# 248   8-Aug-16  107.52  108.37  107.16  108.37  28037220
# 249   5-Aug-16  106.27  107.65  106.18  107.48  40553402
# 250   4-Aug-16  105.58  106.00  105.28  105.87  27408650

# %%
import pandas_datareader.data
from pandas_datareader.data import DataReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e7cf3ef80610> in <module>()
# ----> 1 import pandas_datareader.data
#       2 from pandas_datareader.data import DataReader
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import datetime
dt_start = datetime.datetime(2015, 1, 1)
dt_end = "2016, 6, 30"
